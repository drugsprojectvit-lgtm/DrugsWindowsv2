# %%
import os
import glob
import pandas as pd

# --- CONFIGURATION ---
fda_folder_name = "FDA_approved_drugs"
custom_folders = [
    "FDA_drugs", 
    "FDA_New_drugs"
]

subfolder_name = "07_admet_analysis"

def parse_filename_details(filename):
    """
    Parses a filename like 'SNVK-125_fpocket_pocket1_ligand.pdb'
    Returns: (Name, Tool, Pocket)
    """
    if not isinstance(filename, str) or not filename:
        return "Unknown", "Unknown", "Unknown"
    
    # default values
    name = "Unknown"
    tool = "Unknown"
    pocket = "Unknown"
    
    parts = filename.split('_')
    
    # 1. Extract Name (Always the first part)
    if len(parts) > 0:
        name = parts[0]
        
    # 2. Extract Tool (fpocket or p2rank)
    # We look for specific keywords in the parts
    lower_filename = filename.lower()
    if 'fpocket' in lower_filename:
        tool = 'fpocket'
    elif 'p2rank' in lower_filename:
        tool = 'p2rank'
        
    # 3. Extract Pocket (e.g., pocket1)
    # We look for a part that starts with 'pocket'
    for part in parts:
        if part.lower().startswith('pocket'):
            pocket = part
            break
            
    return name, tool, pocket

def get_fda_benchmark(protein_path):
    """
    Finds the BEST FDA score to serve as the benchmark.
    """
    search_path = os.path.join(protein_path, subfolder_name, "*.csv")
    csv_files = glob.glob(search_path)
    
    if not csv_files:
        return None, None
    
    try:
        df = pd.read_csv(csv_files[0])
        df.columns = df.columns.str.strip()
        
        if 'Docking Score' not in df.columns:
            return None, None
            
        # Sort by score (lowest is best)
        best_row = df.sort_values(by='Docking Score', ascending=True).iloc[0]
        
        score = best_row['Docking Score']
        fname = best_row.get('Filename', '')
        
        # We only need the simple name for the FDA benchmark display
        clean_name, _, _ = parse_filename_details(fname)
        
        return score, clean_name
    except Exception:
        return None, None

def find_better_candidates(protein_path, threshold_score):
    """
    Finds ALL rows where Docking Score < threshold_score.
    """
    search_path = os.path.join(protein_path, subfolder_name, "*.csv")
    csv_files = glob.glob(search_path)
    
    candidates = []
    
    if not csv_files:
        return candidates

    try:
        for csv_file in csv_files:
            df = pd.read_csv(csv_file)
            df.columns = df.columns.str.strip()
            
            if 'Docking Score' not in df.columns:
                continue
            
            # Filter: strictly better (lower) than FDA
            better_df = df[df['Docking Score'] < threshold_score].copy()
            
            for _, row in better_df.iterrows():
                candidates.append(row)
                
    except Exception as e:
        print(f"Error reading custom CSV: {e}")
        
    return candidates

def main():
    # 1. Path Verification
    if not os.path.exists(fda_folder_name):
        print(f"Error: FDA folder '{fda_folder_name}' not found.")
        return

    # 2. Find Intersection of Proteins
    common_proteins = {d for d in os.listdir(fda_folder_name) if os.path.isdir(os.path.join(fda_folder_name, d))}
    
    for cf in custom_folders:
        if os.path.exists(cf):
            c_prots = {d for d in os.listdir(cf) if os.path.isdir(os.path.join(cf, d))}
            common_proteins = common_proteins.intersection(c_prots)
    
    print(f"Analyzing {len(common_proteins)} common proteins...")
    
    final_results = []

    # 3. Process Proteins
    for protein in common_proteins:
        # A. Get FDA Benchmark
        fda_path = os.path.join(fda_folder_name, protein)
        fda_score, fda_name = get_fda_benchmark(fda_path)
        
        if fda_score is None:
            continue 
            
        # B. Check Custom Folders
        for cf in custom_folders:
            custom_path = os.path.join(cf, protein)
            better_rows = find_better_candidates(custom_path, fda_score)
            
            for row in better_rows:
                custom_score = row['Docking Score']
                custom_fname = row.get('Filename', '')
                
                # Parse the filename for specific details
                c_name, c_tool, c_pocket = parse_filename_details(custom_fname)
                
                result_entry = {
                    'Protein': protein,
                    # FDA Benchmark
                    'FDA Name': fda_name,
                    'FDA Score': fda_score,
                    # Custom Candidate Info
                    'Better Ligand': c_name,
                    'Tool': c_tool,      # fpocket / p2rank
                    'Pocket': c_pocket,  # pocket1, pocket2, etc.
                    'Ligand Score': custom_score,
                    'Improvement': round(custom_score - fda_score, 2),
                    # ADMET Data
                    'Decision': row.get('Final Decision', 'N/A'),
                    'SA Score': row.get('SA Score', 'N/A'),
                    'QED': row.get('QED', 'N/A'),
                }
                final_results.append(result_entry)

    # 4. Output
    if final_results:
        df = pd.DataFrame(final_results)
        
        # Sort by Protein then Score
        df = df.sort_values(by=['Protein', 'Ligand Score'])
        
        output_file = "better_than_fda_detailed.csv"
        df.to_csv(output_file, index=False)
        
        print("\n=== BETTER CANDIDATES FOUND ===")
        print(f"Total candidates outperforming FDA: {len(df)}")
        print("-" * 120)
        
        # Define display columns
        cols = ['Protein', 'FDA Name', 'FDA Score', 'Better Ligand', 'Tool', 'Pocket', 'Ligand Score', 'Improvement', 'Decision']
        print(df[cols].to_string(index=False))
        
        print(f"\nDetailed CSV saved to: {output_file}")
    else:
        print("No candidates found that outperform the FDA benchmark.")

if __name__ == "__main__":
    main()
# Out:
# Analyzing 13 common proteins...
#
# === BETTER CANDIDATES FOUND ===
# Total candidates outperforming FDA: 1102
# ------------------------------------------------------------------------------------------------------------------------
# Protein     FDA Name  FDA Score Better Ligand    Tool   Pocket  Ligand Score  Improvement                  Decision
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket2        -10.05        -5.43   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket8        -10.05        -5.43   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16  p2rank  pocket1        -10.03        -5.41   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket8         -9.97        -5.35      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130  p2rank  pocket1         -9.96        -5.34      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket2         -9.81        -5.19      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket8         -9.74        -5.12   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-14  p2rank  pocket1         -9.68        -5.06   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket8         -9.67        -5.05      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-13  p2rank  pocket1         -9.66        -5.04      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket2         -9.65        -5.03   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket8         -9.63        -5.01   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket2         -9.62        -5.00   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-140  p2rank  pocket1         -9.61        -4.99      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket2         -9.61        -4.99      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-155  p2rank  pocket1         -9.60        -4.98   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-152  p2rank  pocket1         -9.59        -4.97      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket2         -9.58        -4.96      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket2         -9.58        -4.96      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket8         -9.58        -4.96   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket2         -9.57        -4.95   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19  p2rank  pocket1         -9.57        -4.95   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket2         -9.52        -4.90      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151  p2rank  pocket1         -9.51        -4.89      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket2         -9.50        -4.88   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket8         -9.49        -4.87      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17  p2rank  pocket1         -9.47        -4.85   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket8         -9.37        -4.75      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket2         -9.36        -4.74      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket8         -9.33        -4.71      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-153  p2rank  pocket1         -9.33        -4.71      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket8         -9.31        -4.69   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket8         -9.27        -4.65   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket2         -9.26        -4.64   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20  p2rank  pocket1         -9.26        -4.64   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket8         -9.20        -4.58   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15  p2rank  pocket1         -9.20        -4.58   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket2         -9.17        -4.55   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket8         -9.15        -4.53   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-12  p2rank  pocket1         -9.14        -4.52   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket8         -9.13        -4.51      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-11  p2rank  pocket1         -9.12        -4.50   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket8         -9.11        -4.49   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket2         -9.08        -4.46   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket2         -9.07        -4.45   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket8         -9.06        -4.44   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket2         -9.04        -4.42   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160  p2rank  pocket1         -9.03        -4.41   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket2         -8.96        -4.34   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18  p2rank  pocket1         -8.96        -4.34   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket8         -8.92        -4.30      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-146  p2rank  pocket1         -8.91        -4.29      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket8         -8.91        -4.29   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket2         -8.89        -4.27      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158  p2rank  pocket1         -8.87        -4.25      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket8         -8.82        -4.20      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket2         -8.80        -4.18      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-16  p2rank  pocket2         -8.70        -4.08   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket2         -8.64        -4.02 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket8         -8.63        -4.01 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143  p2rank  pocket1         -8.62        -4.00 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-144  p2rank  pocket1         -8.54        -3.92      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket2         -8.52        -3.90      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket8         -8.52        -3.90      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132  p2rank  pocket1         -8.46        -3.84      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket2         -8.42        -3.80      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket8         -8.42        -3.80      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket8         -8.41        -3.79 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket4         -8.41        -3.79   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket2         -8.40        -3.78      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket8         -8.40        -3.78      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket2         -8.40        -3.78 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157  p2rank  pocket1         -8.40        -3.78 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149  p2rank  pocket1         -8.34        -3.72 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SNVK-125  p2rank  pocket1         -8.33        -3.71      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket8         -8.30        -3.68 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket2         -8.25        -3.63 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SKNKS-11  p2rank  pocket2         -8.16        -3.54   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket pocket10         -8.10        -3.48   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket2         -8.02        -3.40      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-133  p2rank  pocket1         -7.99        -3.37      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket8         -7.94        -3.32      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket pocket10         -7.91        -3.29      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket6         -7.84        -3.22      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket pocket10         -7.77        -3.15   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-140  p2rank  pocket2         -7.76        -3.14      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket4         -7.75        -3.13      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket4         -7.72        -3.10      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130  p2rank  pocket2         -7.71        -3.09      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket6         -7.62        -3.00      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-160  p2rank  pocket2         -7.58        -2.96   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket pocket10         -7.53        -2.91   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-12  p2rank  pocket2         -7.52        -2.90   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket pocket11         -7.51        -2.89      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-20  p2rank  pocket2         -7.51        -2.89   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-17  p2rank  pocket2         -7.50        -2.88   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket pocket11         -7.50        -2.88   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket4         -7.50        -2.88   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket4         -7.49        -2.87      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket4         -7.48        -2.86   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket6         -7.47        -2.85      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket pocket11         -7.46        -2.84      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket4         -7.46        -2.84   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket pocket11         -7.45        -2.83   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13  p2rank  pocket2         -7.44        -2.82      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62     SVNKS-151  p2rank  pocket2         -7.43        -2.81      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket4         -7.43        -2.81      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket4         -7.38        -2.76   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket pocket10         -7.37        -2.75   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket4         -7.32        -2.70   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket6         -7.32        -2.70   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket6         -7.28        -2.66   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket pocket11         -7.27        -2.65   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket pocket11         -7.27        -2.65      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket pocket11         -7.27        -2.65   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket4         -7.26        -2.64   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket6         -7.26        -2.64      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket6         -7.26        -2.64   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19  p2rank  pocket2         -7.25        -2.63   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155  p2rank  pocket2         -7.20        -2.58   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket4         -7.20        -2.58   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket pocket11         -7.18        -2.56   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-14  p2rank  pocket2         -7.18        -2.56   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket pocket10         -7.17        -2.55      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket6         -7.17        -2.55   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket4         -7.15        -2.53   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket6         -7.15        -2.53   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket4         -7.14        -2.52      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket6         -7.13        -2.51   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket4         -7.13        -2.51   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket7         -7.12        -2.50   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket4         -7.12        -2.50   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket6         -7.11        -2.49   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18  p2rank  pocket2         -7.11        -2.49   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket6         -7.10        -2.48      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-15  p2rank  pocket2         -7.10        -2.48   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket pocket11         -7.10        -2.48   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket6         -7.10        -2.48   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153  p2rank  pocket2         -7.09        -2.47      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket pocket11         -7.09        -2.47   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket pocket11         -7.09        -2.47   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket6         -7.07        -2.45   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket pocket11         -7.02        -2.40   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket6         -6.99        -2.37   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket7         -6.99        -2.37   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket4         -6.98        -2.36      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket4         -6.98        -2.36      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket pocket11         -6.98        -2.36   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-152  p2rank  pocket2         -6.97        -2.35      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket6         -6.95        -2.33      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132  p2rank  pocket2         -6.94        -2.32      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket pocket11         -6.92        -2.30      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket6         -6.90        -2.28   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket7         -6.88        -2.26      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket6         -6.87        -2.25      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket6         -6.87        -2.25      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket4         -6.77        -2.15      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket pocket10         -6.76        -2.14      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket pocket10         -6.76        -2.14 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-146  p2rank  pocket2         -6.75        -2.13      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket7         -6.75        -2.13      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket1         -6.74        -2.12   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket7         -6.72        -2.10      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket7         -6.71        -2.09      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket pocket11         -6.71        -2.09      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket7         -6.71        -2.09      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket pocket11         -6.70        -2.08      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket pocket10         -6.68        -2.06      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket6         -6.67        -2.05      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket4         -6.66        -2.04      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-125  p2rank  pocket2         -6.66        -2.04      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket7         -6.63        -2.01   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket pocket11         -6.60        -1.98   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket pocket10         -6.60        -1.98   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket7         -6.60        -1.98   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket7         -6.56        -1.94      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158  p2rank  pocket2         -6.56        -1.94      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket1         -6.56        -1.94   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket1         -6.54        -1.92   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket6         -6.53        -1.91      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket6         -6.52        -1.90      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket4         -6.47        -1.85      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket1         -6.47        -1.85      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket pocket11         -6.47        -1.85      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144  p2rank  pocket2         -6.45        -1.83      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket7         -6.45        -1.83   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket7         -6.44        -1.82      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket pocket10         -6.44        -1.82      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket7         -6.44        -1.82   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket1         -6.42        -1.80   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket7         -6.42        -1.80   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket7         -6.41        -1.79   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket4         -6.40        -1.78 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket6         -6.40        -1.78 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SKNKS-18  p2rank  pocket3         -6.40        -1.78   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket3         -6.39        -1.77   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket1         -6.39        -1.77   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket7         -6.39        -1.77   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket pocket10         -6.37        -1.75   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket7         -6.37        -1.75   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-151  p2rank  pocket3         -6.36        -1.74      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-160  p2rank  pocket3         -6.36        -1.74   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket7         -6.35        -1.73   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket4         -6.34        -1.72 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket pocket10         -6.33        -1.71      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket1         -6.33        -1.71   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket1         -6.32        -1.70      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket3         -6.32        -1.70      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-157  p2rank  pocket2         -6.32        -1.70 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket1         -6.32        -1.70   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-17  p2rank  pocket3         -6.32        -1.70   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket4         -6.30        -1.68      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket pocket10         -6.30        -1.68   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket pocket10         -6.27        -1.65      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket3         -6.27        -1.65   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20  p2rank  pocket3         -6.27        -1.65   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket4         -6.26        -1.64      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-149  p2rank  pocket2         -6.26        -1.64 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket6         -6.26        -1.64 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-133  p2rank  pocket2         -6.24        -1.62      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket pocket10         -6.24        -1.62      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket1         -6.24        -1.62      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-140  p2rank  pocket3         -6.23        -1.61      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket pocket11         -6.21        -1.59      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket3         -6.21        -1.59      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket3         -6.21        -1.59   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-12  p2rank  pocket3         -6.21        -1.59   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket pocket11         -6.20        -1.58      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-143  p2rank  pocket2         -6.20        -1.58 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket1         -6.20        -1.58   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13  p2rank  pocket3         -6.20        -1.58      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-16  p2rank  pocket3         -6.20        -1.58   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket4         -6.19        -1.57 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket6         -6.19        -1.57 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SKNKS-11  p2rank  pocket3         -6.19        -1.57   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155  p2rank  pocket3         -6.18        -1.56   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket3         -6.17        -1.55      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket pocket11         -6.16        -1.54      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket3         -6.16        -1.54   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket1         -6.15        -1.53      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-14  p2rank  pocket3         -6.15        -1.53   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket pocket10         -6.14        -1.52      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket7         -6.13        -1.51      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket pocket10         -6.12        -1.50      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket pocket10         -6.12        -1.50   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket3         -6.11        -1.49      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-153  p2rank  pocket3         -6.10        -1.48      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket pocket10         -6.09        -1.47   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket1         -6.08        -1.46      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket3         -6.08        -1.46   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket3         -6.08        -1.46   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket1         -6.08        -1.46   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket9         -6.07        -1.45   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket3         -6.04        -1.42      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130  p2rank  pocket3         -6.04        -1.42      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket1         -6.04        -1.42      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket3         -6.04        -1.42      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket3         -6.04        -1.42   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket pocket10         -6.04        -1.42   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-16 fpocket  pocket5         -6.03        -1.41   REJECT (DILI High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket9         -6.02        -1.40   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket9         -6.01        -1.39      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-19  p2rank  pocket3         -6.01        -1.39   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket6         -6.00        -1.38      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket pocket10         -6.00        -1.38      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158  p2rank  pocket3         -6.00        -1.38      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket9         -5.99        -1.37      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket1         -5.97        -1.35   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket3         -5.97        -1.35   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-13 fpocket  pocket5         -5.97        -1.35      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket3         -5.97        -1.35   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket pocket11         -5.96        -1.34      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152  p2rank  pocket3         -5.94        -1.32      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket3         -5.93        -1.31      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket pocket11         -5.92        -1.30      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket1         -5.92        -1.30      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket pocket11         -5.91        -1.29 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket pocket11         -5.89        -1.27 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket7         -5.88        -1.26 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket7         -5.86        -1.24      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket9         -5.85        -1.23   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket7         -5.84        -1.22      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-15  p2rank  pocket3         -5.84        -1.22   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket9         -5.84        -1.22   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket1         -5.83        -1.21      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket9         -5.82        -1.20      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket9         -5.82        -1.20      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket9         -5.80        -1.18      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket7         -5.80        -1.18      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket3         -5.80        -1.18   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket1         -5.78        -1.16 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket3         -5.78        -1.16   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket7         -5.77        -1.15      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket9         -5.77        -1.15   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket pocket10         -5.76        -1.14   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket9         -5.74        -1.12   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket3         -5.71        -1.09      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket9         -5.71        -1.09   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SNVK-125  p2rank  pocket3         -5.70        -1.08      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket1         -5.70        -1.08      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket1         -5.70        -1.08   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket9         -5.70        -1.08   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-155 fpocket  pocket5         -5.69        -1.07   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-12 fpocket  pocket5         -5.69        -1.07   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket1         -5.65        -1.03      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-130 fpocket  pocket5         -5.64        -1.02      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket9         -5.64        -1.02   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket9         -5.59        -0.97      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket9         -5.59        -0.97   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket pocket10         -5.57        -0.95 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SKNKS-14 fpocket  pocket5         -5.57        -0.95   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-158 fpocket  pocket5         -5.56        -0.94      REJECT (Brenk Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket1         -5.55        -0.93      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket pocket11         -5.54        -0.92 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket9         -5.53        -0.91      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-19 fpocket  pocket5         -5.53        -0.91   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-18 fpocket  pocket5         -5.52        -0.90   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-20 fpocket  pocket5         -5.52        -0.90   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket1         -5.51        -0.89      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-146  p2rank  pocket3         -5.49        -0.87      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket7         -5.49        -0.87 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-160 fpocket  pocket5         -5.49        -0.87   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket7         -5.48        -0.86 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket9         -5.47        -0.85      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket9         -5.45        -0.83      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132  p2rank  pocket3         -5.45        -0.83      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket pocket10         -5.45        -0.83 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket5         -5.44        -0.82      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket9         -5.44        -0.82      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-146 fpocket  pocket3         -5.43        -0.81      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket3         -5.42        -0.80      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-11 fpocket  pocket5         -5.41        -0.79   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket pocket10         -5.40        -0.78      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-17 fpocket  pocket5         -5.40        -0.78   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket5         -5.39        -0.77   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket5         -5.35        -0.73      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-132 fpocket  pocket5         -5.34        -0.72      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-157  p2rank  pocket3         -5.34        -0.72 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-133  p2rank  pocket3         -5.31        -0.69      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SKNKS-15 fpocket  pocket9         -5.31        -0.69   REJECT (hERG High Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket5         -5.30        -0.68 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket9         -5.30        -0.68 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket3         -5.29        -0.67 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket9         -5.28        -0.66 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket1         -5.26        -0.64 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket5         -5.25        -0.63      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-133 fpocket  pocket3         -5.25        -0.63      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-149  p2rank  pocket3         -5.24        -0.62 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket3         -5.24        -0.62 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-153 fpocket  pocket5         -5.23        -0.61      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62      SNVK-125 fpocket  pocket9         -5.21        -0.59      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-151 fpocket  pocket5         -5.21        -0.59      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-143  p2rank  pocket3         -5.21        -0.59 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket9         -5.21        -0.59 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket1         -5.18        -0.56 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket3         -5.15        -0.53      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket9         -5.09        -0.47      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-152 fpocket  pocket5         -5.08        -0.46      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-140 fpocket  pocket5         -5.07        -0.45      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62     SVNKS-144  p2rank  pocket3         -5.07        -0.45      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-143 fpocket  pocket3         -5.04        -0.42 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62   SVNKS-R-157 fpocket  pocket5         -4.96        -0.34 REVIEW (hERG Medium Risk)
#    AMPK    Metformin      -4.62     SVNKS-144 fpocket  pocket5         -4.91        -0.29      REJECT (PAINS Alert)
#    AMPK    Metformin      -4.62   SVNKS-R-149 fpocket  pocket5         -4.89        -0.27 REVIEW (hERG Medium Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-16 fpocket pocket10         -8.82        -2.09   REJECT (DILI High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-16 fpocket  pocket1         -8.82        -2.09   REJECT (DILI High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-16  p2rank  pocket1         -8.81        -2.08   REJECT (DILI High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-16 fpocket  pocket7         -8.78        -2.05   REJECT (DILI High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-16  p2rank  pocket7         -8.78        -2.05   REJECT (DILI High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-16 fpocket pocket14         -8.75        -2.02   REJECT (DILI High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-11 fpocket pocket13         -8.58        -1.85   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20  p2rank  pocket2         -8.58        -1.85   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20 fpocket  pocket7         -8.57        -1.84   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-11 fpocket pocket12         -8.55        -1.82   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-11  p2rank  pocket5         -8.55        -1.82   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20 fpocket pocket10         -8.55        -1.82   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20 fpocket pocket14         -8.53        -1.80   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20  p2rank  pocket7         -8.53        -1.80   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12 fpocket pocket12         -8.50        -1.77   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12 fpocket pocket14         -8.49        -1.76   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12 fpocket  pocket7         -8.49        -1.76   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20  p2rank  pocket1         -8.49        -1.76   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12 fpocket pocket10         -8.48        -1.75   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12  p2rank  pocket5         -8.48        -1.75   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12 fpocket pocket13         -8.47        -1.74   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12  p2rank  pocket1         -8.46        -1.73   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12  p2rank  pocket2         -8.41        -1.68   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20 fpocket pocket12         -8.41        -1.68   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-12  p2rank  pocket7         -8.39        -1.66   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20 fpocket pocket13         -8.38        -1.65   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-20  p2rank  pocket5         -8.38        -1.65   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-13 fpocket pocket13         -8.36        -1.63      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-13  p2rank  pocket7         -8.36        -1.63      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-17 fpocket pocket12         -8.36        -1.63   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-17 fpocket pocket13         -8.36        -1.63   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-13 fpocket pocket10         -8.35        -1.62      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-13 fpocket pocket14         -8.35        -1.62      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-13 fpocket  pocket1         -8.35        -1.62      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-13  p2rank  pocket5         -8.35        -1.62      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-16 fpocket pocket13         -8.35        -1.62   REJECT (DILI High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-17 fpocket pocket14         -8.35        -1.62   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-17 fpocket  pocket1         -8.34        -1.61   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-17  p2rank  pocket7         -8.34        -1.61   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SKNKS-17  p2rank  pocket9         -8.34        -1.61   REJECT (hERG High Risk)
#    EGFR    Erlotinib      -6.73      SNVK-130  p2rank  pocket1         -8.33        -1.60      REJECT (PAINS Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-13 fpocket pocket12         -8.33        -1.60      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-13 fpocket  pocket7         -8.33        -1.60      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SKNKS-13  p2rank  pocket9         -8.33        -1.60      REJECT (Brenk Alert)
#    EGFR    Erlotinib      -6.73      SNVK-130 fpocket pocket10         -8.32        -1.59      REJECT (PAINS Alert)
#    EGFR    Erlotinib      -6.73      SNVK-130 fpocket  pocket7         -8.32        -1.59      REJECT (PAINS Alert)
# ...
#    JAK1 Upadacitinib      -8.10      SKNKS-20 fpocket  pocket9         -8.12        -0.02   REJECT (hERG High Risk)
#    JAK1 Upadacitinib      -8.10     SVNKS-153 fpocket  pocket3         -8.11        -0.01      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-13  p2rank  pocket1        -10.24        -2.80      REJECT (Brenk Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-13 fpocket  pocket1        -10.20        -2.76      REJECT (Brenk Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-16 fpocket  pocket1        -10.15        -2.71   REJECT (DILI High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-16  p2rank  pocket1        -10.10        -2.66   REJECT (DILI High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-11  p2rank  pocket1         -9.93        -2.49   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-11 fpocket  pocket1         -9.90        -2.46   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-19  p2rank  pocket1         -9.87        -2.43   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-19 fpocket  pocket1         -9.84        -2.40   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-12  p2rank  pocket1         -9.83        -2.39   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-12 fpocket  pocket1         -9.82        -2.38   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-14 fpocket  pocket1         -9.80        -2.36   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-14  p2rank  pocket1         -9.80        -2.36   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SNVK-130 fpocket  pocket1         -9.70        -2.26      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-20  p2rank  pocket1         -9.70        -2.26   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-20 fpocket  pocket1         -9.69        -2.25   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44     SVNKS-140 fpocket  pocket1         -9.62        -2.18      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-140  p2rank  pocket1         -9.52        -2.08      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-15  p2rank  pocket1         -9.49        -2.05   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-15 fpocket  pocket1         -9.48        -2.04   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-18 fpocket  pocket1         -9.46        -2.02   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-18  p2rank  pocket1         -9.46        -2.02   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SNVK-130  p2rank  pocket1         -9.43        -1.99      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-17 fpocket  pocket1         -9.41        -1.97   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-17  p2rank  pocket1         -9.40        -1.96   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-155  p2rank  pocket1         -8.50        -1.06   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-155 fpocket  pocket1         -8.49        -1.05   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-158 fpocket  pocket1         -8.45        -1.01      REJECT (Brenk Alert)
#    KRAS    Sotorasib      -7.44   SVNKS-R-158  p2rank  pocket1         -8.43        -0.99      REJECT (Brenk Alert)
#    KRAS    Sotorasib      -7.44   SVNKS-R-160  p2rank  pocket1         -8.38        -0.94   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-160 fpocket  pocket1         -8.36        -0.92   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-143 fpocket  pocket1         -8.20        -0.76 REVIEW (hERG Medium Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-143  p2rank  pocket1         -8.13        -0.69 REVIEW (hERG Medium Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-149 fpocket  pocket1         -8.11        -0.67 REVIEW (hERG Medium Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-149  p2rank  pocket1         -8.09        -0.65 REVIEW (hERG Medium Risk)
#    KRAS    Sotorasib      -7.44     SVNKS-144  p2rank  pocket1         -8.05        -0.61      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-144 fpocket  pocket1         -8.03        -0.59      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44   SVNKS-R-157  p2rank  pocket1         -7.99        -0.55 REVIEW (hERG Medium Risk)
#    KRAS    Sotorasib      -7.44     SVNKS-133  p2rank  pocket1         -7.94        -0.50      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-133 fpocket  pocket1         -7.92        -0.48      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-153  p2rank  pocket1         -7.90        -0.46      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-132 fpocket  pocket1         -7.89        -0.45      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-153 fpocket  pocket1         -7.89        -0.45      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-132  p2rank  pocket1         -7.88        -0.44      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-152  p2rank  pocket1         -7.87        -0.43      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-151  p2rank  pocket1         -7.84        -0.40      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44      SNVK-125 fpocket  pocket1         -7.82        -0.38      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-151 fpocket  pocket1         -7.81        -0.37      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-140 fpocket  pocket8         -7.69        -0.25      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-140  p2rank  pocket4         -7.67        -0.23      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-140 fpocket  pocket5         -7.66        -0.22      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-146 fpocket  pocket1         -7.65        -0.21      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44     SVNKS-152 fpocket  pocket1         -7.64        -0.20      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-18  p2rank  pocket3         -7.62        -0.18   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-16 fpocket  pocket4         -7.59        -0.15   REJECT (DILI High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-16  p2rank  pocket4         -7.59        -0.15   REJECT (DILI High Risk)
#    KRAS    Sotorasib      -7.44      SKNKS-16 fpocket  pocket8         -7.58        -0.14   REJECT (DILI High Risk)
#    KRAS    Sotorasib      -7.44     SVNKS-146  p2rank  pocket1         -7.57        -0.13      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44      SKNKS-18 fpocket  pocket7         -7.57        -0.13   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44     SVNKS-153 fpocket  pocket5         -7.50        -0.06      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44   SVNKS-R-155  p2rank  pocket4         -7.48        -0.04   REJECT (hERG High Risk)
#    KRAS    Sotorasib      -7.44   SVNKS-R-157 fpocket  pocket1         -7.47        -0.03 REVIEW (hERG Medium Risk)
#    KRAS    Sotorasib      -7.44     SVNKS-153  p2rank  pocket4         -7.46        -0.02      REJECT (PAINS Alert)
#    KRAS    Sotorasib      -7.44   SVNKS-R-155 fpocket  pocket8         -7.45        -0.01   REJECT (hERG High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-14 fpocket  pocket2         -8.98        -0.31   REJECT (hERG High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-14  p2rank  pocket2         -8.98        -0.31   REJECT (hERG High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-11 fpocket  pocket2         -8.97        -0.30   REJECT (hERG High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-11  p2rank  pocket2         -8.95        -0.28   REJECT (hERG High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-19  p2rank  pocket2         -8.91        -0.24   REJECT (hERG High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-13  p2rank  pocket2         -8.87        -0.20      REJECT (Brenk Alert)
#   PARP1     Olaparib      -8.67      SKNKS-19 fpocket  pocket2         -8.87        -0.20   REJECT (hERG High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-13 fpocket  pocket2         -8.85        -0.18      REJECT (Brenk Alert)
#   PARP1     Olaparib      -8.67      SKNKS-16  p2rank  pocket2         -8.85        -0.18   REJECT (DILI High Risk)
#   PARP1     Olaparib      -8.67      SKNKS-16 fpocket  pocket2         -8.84        -0.17   REJECT (DILI High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-140 fpocket  pocket2         -7.90        -0.57      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-140  p2rank  pocket2         -7.82        -0.49      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-151 fpocket  pocket2         -7.77        -0.44      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-13 fpocket  pocket2         -7.73        -0.40      REJECT (Brenk Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-153  p2rank  pocket1         -7.71        -0.38      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-13  p2rank  pocket2         -7.71        -0.38      REJECT (Brenk Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-20 fpocket  pocket2         -7.68        -0.35   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-153 fpocket  pocket5         -7.63        -0.30      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-155 fpocket  pocket7         -7.63        -0.30   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33   SVNKS-R-155 fpocket  pocket6         -7.62        -0.29   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-140  p2rank  pocket1         -7.61        -0.28      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-149  p2rank  pocket1         -7.61        -0.28 REVIEW (hERG Medium Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-13  p2rank  pocket1         -7.61        -0.28      REJECT (Brenk Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-140 fpocket  pocket1         -7.60        -0.27      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-151 fpocket  pocket1         -7.60        -0.27      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-13 fpocket  pocket1         -7.60        -0.27      REJECT (Brenk Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-13 fpocket  pocket5         -7.60        -0.27      REJECT (Brenk Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-17 fpocket  pocket2         -7.60        -0.27   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-140 fpocket  pocket5         -7.59        -0.26      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-151  p2rank  pocket1         -7.59        -0.26      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-151 fpocket  pocket5         -7.58        -0.25      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-149 fpocket  pocket1         -7.58        -0.25 REVIEW (hERG Medium Risk)
#    PI3K    Alpelisib      -7.33      SNVK-130  p2rank  pocket2         -7.56        -0.23      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-15  p2rank  pocket2         -7.56        -0.23   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33   SVNKS-R-155 fpocket  pocket2         -7.55        -0.22   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-153 fpocket  pocket1         -7.54        -0.21      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-15 fpocket  pocket2         -7.54        -0.21   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-20 fpocket  pocket6         -7.54        -0.21   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33   SVNKS-R-160 fpocket  pocket1         -7.53        -0.20   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SNVK-125 fpocket  pocket5         -7.52        -0.19      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-155 fpocket  pocket5         -7.52        -0.19   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33   SVNKS-R-155  p2rank  pocket1         -7.52        -0.19   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-16 fpocket  pocket2         -7.52        -0.19   REJECT (DILI High Risk)
#    PI3K    Alpelisib      -7.33      SNVK-125 fpocket  pocket1         -7.50        -0.17      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SNVK-125  p2rank  pocket1         -7.50        -0.17      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SNVK-130 fpocket  pocket1         -7.50        -0.17      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-132 fpocket  pocket1         -7.50        -0.17      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-16  p2rank  pocket2         -7.50        -0.17   REJECT (DILI High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-132 fpocket  pocket5         -7.49        -0.16      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-155  p2rank  pocket2         -7.49        -0.16   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33   SVNKS-R-160  p2rank  pocket1         -7.49        -0.16   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SNVK-130 fpocket  pocket2         -7.48        -0.15      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-155 fpocket  pocket1         -7.48        -0.15   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33   SVNKS-R-160 fpocket  pocket5         -7.48        -0.15   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-14  p2rank  pocket2         -7.48        -0.15   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-132  p2rank  pocket1         -7.45        -0.12      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-14 fpocket  pocket2         -7.45        -0.12   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-17  p2rank  pocket2         -7.45        -0.12   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SNVK-130  p2rank  pocket1         -7.44        -0.11      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-11 fpocket  pocket6         -7.41        -0.08   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SNVK-130 fpocket  pocket5         -7.40        -0.07      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-160  p2rank  pocket2         -7.40        -0.07   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-12 fpocket  pocket2         -7.40        -0.07   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-152 fpocket  pocket6         -7.38        -0.05      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33   SVNKS-R-160 fpocket  pocket2         -7.38        -0.05   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-12 fpocket  pocket6         -7.37        -0.04   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-11 fpocket  pocket2         -7.36        -0.03   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33      SKNKS-11 fpocket  pocket7         -7.36        -0.03   REJECT (hERG High Risk)
#    PI3K    Alpelisib      -7.33     SVNKS-153 fpocket  pocket6         -7.35        -0.02      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-152 fpocket  pocket2         -7.34        -0.01      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33     SVNKS-153  p2rank  pocket2         -7.34        -0.01      REJECT (PAINS Alert)
#    PI3K    Alpelisib      -7.33      SKNKS-12  p2rank  pocket2         -7.34        -0.01   REJECT (hERG High Risk)
#
# Detailed CSV saved to: better_than_fda_detailed.csv

# %%
import os
import subprocess

def convert_sdf_to_pdbqt(input_folder, output_folder=None):
    # 1. Setup paths
    # If no output folder is defined, save files in the same folder as input
    if output_folder is None:
        output_folder = input_folder
    
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    print(f"Processing files in: {input_folder}")

    # 2. Loop through all files
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(".sdf"):
            input_path = os.path.join(input_folder, filename)
            
            # Create the output filename (replace extension)
            base_name = os.path.splitext(filename)[0]
            output_path = os.path.join(output_folder, f"{base_name}.pdbqt")
            
            # 3. Construct the Open Babel command
            # -isdf : Input format
            # -opdbqt : Output format
            # -O : Output file path
            # -h : Add hydrogens (Required for docking)
            # --partialcharge gasteiger : Add charges (Required for docking)
            command = [
                "obabel",
                "-isdf", input_path,
                "-opdbqt", "-O", output_path,
                "-h",
                "--partialcharge", "gasteiger"
            ]
            
            # 4. Run the command
            try:
                # stdout=subprocess.DEVNULL hides the verbose logs from obabel
                subprocess.run(command, check=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                print(f"[SUCCESS] Converted: {filename}")
            except subprocess.CalledProcessError:
                print(f"[ERROR] Failed to convert: {filename}")
            except FileNotFoundError:
                print("Error: 'obabel' command not found. Is Open Babel installed and added to your PATH?")
                break

# --- USAGE ---
# UPDATE THIS PATH to point to your specific folder
# Use r"" to handle Windows backslashes
my_input_folder = r"SKNKS_Series 3 Mol format"
my_output_folder = r"pdbqt_new_v2"

if __name__ == "__main__":
    convert_sdf_to_pdbqt(my_input_folder, my_output_folder)
# Out:
# Processing files in: SKNKS_Series 3 Mol format
# [SUCCESS] Converted: SKNKS 1.sdf
# [SUCCESS] Converted: SKNKS-10.sdf
# [SUCCESS] Converted: SKNKS-11.sdf
# [SUCCESS] Converted: SKNKS-12.sdf
# [SUCCESS] Converted: SKNKS-13.sdf
# [SUCCESS] Converted: SKNKS-14.sdf
# [SUCCESS] Converted: SKNKS-15.sdf
# [SUCCESS] Converted: SKNKS-16.sdf
# [SUCCESS] Converted: SKNKS-17.sdf
# [SUCCESS] Converted: SKNKS-18.sdf
# [SUCCESS] Converted: SKNKS-19.sdf
# [SUCCESS] Converted: SKNKS-2.sdf
# [SUCCESS] Converted: SKNKS-20.sdf
# [SUCCESS] Converted: SKNKS-3.sdf
# [SUCCESS] Converted: SKNKS-4.sdf
# [SUCCESS] Converted: SKNKS-5.sdf
# [SUCCESS] Converted: SKNKS-6.sdf
# [SUCCESS] Converted: SKNKS-7.sdf
# [SUCCESS] Converted: SKNKS-8.sdf
# [SUCCESS] Converted: SKNKS-9.sdf
